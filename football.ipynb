# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
import pandas as pd
data = pd.read_csv('/Users/yasmin/Downloads/results.csv')
data
# Out:
#              date     home_team   away_team  home_score  away_score  \
# 0      1872-11-30      Scotland     England           0           0
# 1      1873-03-08       England    Scotland           4           2
# 2      1874-03-07      Scotland     England           2           1
# 3      1875-03-06       England    Scotland           2           2
# 4      1876-03-04      Scotland     England           3           0
# ...           ...           ...         ...         ...         ...
# 41238  2019-10-20       Lesotho    Zimbabwe           0           0
# 41239  2019-10-20        Guinea     Senegal           1           0
# 41240  2019-10-20          Mali  Mauritania           2           0
# 41241  2019-10-20  Burkina Faso       Ghana           0           0
# 41242  2019-10-20   Ivory Coast       Niger           1           0
#
#                                     tournament          city       country  \
# ...

# %%
data['date'] = pd.to_datetime(data.date)

# %%
data
# Out:
#             date     home_team   away_team  home_score  away_score  \
# 0     1872-11-30      Scotland     England           0           0
# 1     1873-03-08       England    Scotland           4           2
# 2     1874-03-07      Scotland     England           2           1
# 3     1875-03-06       England    Scotland           2           2
# 4     1876-03-04      Scotland     England           3           0
# ...          ...           ...         ...         ...         ...
# 41238 2019-10-20       Lesotho    Zimbabwe           0           0
# 41239 2019-10-20        Guinea     Senegal           1           0
# 41240 2019-10-20          Mali  Mauritania           2           0
# 41241 2019-10-20  Burkina Faso       Ghana           0           0
# 41242 2019-10-20   Ivory Coast       Niger           1           0
#
#                                     tournament          city       country  \
# 0                                     Friendly       Glasgow      Scotland
# ...

# %%
data.date.dt.year.value_counts().sort_index().head()
# Out:
# 1872    1
# 1873    1
# 1874    1
# 1875    1
# 1876    2
# Name: date, dtype: int64

# %%
data.date.dt.year.value_counts().sort_index().plot()

# %%
data.date.dt.year[data.date.dt.year >= 2009].value_counts().sort_index().plot()

# %%
data['goals'] = data.home_score + data.away_score
data
# Out:
#             date     home_team   away_team  home_score  away_score  \
# 0     1872-11-30      Scotland     England           0           0
# 1     1873-03-08       England    Scotland           4           2
# 2     1874-03-07      Scotland     England           2           1
# 3     1875-03-06       England    Scotland           2           2
# 4     1876-03-04      Scotland     England           3           0
# ...          ...           ...         ...         ...         ...
# 41238 2019-10-20       Lesotho    Zimbabwe           0           0
# 41239 2019-10-20        Guinea     Senegal           1           0
# 41240 2019-10-20          Mali  Mauritania           2           0
# 41241 2019-10-20  Burkina Faso       Ghana           0           0
# 41242 2019-10-20   Ivory Coast       Niger           1           0
#
#                                     tournament          city       country  \
# 0                                     Friendly       Glasgow      Scotland
# ...

# %%
data[['home_score','away_score','goals']]
# Out:
#        home_score  away_score  goals
# 0               0           0      0
# 1               4           2      6
# 2               2           1      3
# 3               2           2      4
# 4               3           0      3
# ...           ...         ...    ...
# 41238           0           0      0
# 41239           1           0      1
# 41240           2           0      2
# 41241           0           0      0
# 41242           1           0      1
#
# [41243 rows x 3 columns]

# %%
data.tournament.value_counts()
# Out:
# Friendly                                17011
# FIFA World Cup qualification             7100
# UEFA Euro qualification                  2532
# African Cup of Nations qualification     1624
# FIFA World Cup                            900
#                                         ...
# Dragon Cup                                  4
# World Unity Cup                             4
# Copa América qualification                  2
# AFF Championship qualification              2
# Atlantic Heritage Cup                       2
# Name: tournament, Length: 112, dtype: int64

# %%
tcount = data.tournament.value_counts()

# %%
top = tcount[tcount >= 100]
top
# Out:
# Friendly                                17011
# FIFA World Cup qualification             7100
# UEFA Euro qualification                  2532
# African Cup of Nations qualification     1624
# FIFA World Cup                            900
# Copa América                              813
# AFC Asian Cup qualification               724
# African Cup of Nations                    690
# CECAFA Cup                                620
# CFU Caribbean Cup qualification           606
# Merdeka Tournament                        503
# British Championship                      501
# AFC Asian Cup                             370
# Island Games                              350
# Gulf Cup                                  333
# Gold Cup                                  327
# AFF Championship                          293
# COSAFA Cup                                292
# UEFA Euro                                 286
# Nordic Championship                       283
# ...

# %%
top = tcount[tcount >= 100].index
top
# Out:
# Index(['Friendly', 'FIFA World Cup qualification', 'UEFA Euro qualification',
#        'African Cup of Nations qualification', 'FIFA World Cup',
#        'Copa América', 'AFC Asian Cup qualification', 'African Cup of Nations',
#        'CECAFA Cup', 'CFU Caribbean Cup qualification', 'Merdeka Tournament',
#        'British Championship', 'AFC Asian Cup', 'Island Games', 'Gulf Cup',
#        'Gold Cup', 'AFF Championship', 'COSAFA Cup', 'UEFA Euro',
#        'Nordic Championship', 'African Nations Championship',
#        'CFU Caribbean Cup', 'Amílcar Cabral Cup', 'King's Cup',
#        'South Pacific Games', 'UNCAF Cup', 'Korea Cup', 'UEFA Nations League',
#        'Confederations Cup', 'SAFF Cup', 'International Cup',
#        'CCCF Championship', 'UAFA Cup', 'EAFF Championship',
#        'Oceania Nations Cup', 'Windward Islands Tournament',
#        'CONIFA World Football Cup', 'AFC Challenge Cup'],
#       dtype='object')

# %%
newdata = data[data.tournament.isin(top)]
newdata
# Out:
#             date   home_team     away_team  home_score  away_score tournament  \
# 0     1872-11-30    Scotland       England           0           0   Friendly
# 1     1873-03-08     England      Scotland           4           2   Friendly
# 2     1874-03-07    Scotland       England           2           1   Friendly
# 3     1875-03-06     England      Scotland           2           2   Friendly
# 4     1876-03-04    Scotland       England           3           0   Friendly
# ...          ...         ...           ...         ...         ...        ...
# 41215 2019-10-15     Denmark    Luxembourg           4           0   Friendly
# 41216 2019-10-15      Kuwait  Turkmenistan           1           1   Friendly
# 41217 2019-10-15  Mauritania         Libya           0           0   Friendly
# 41218 2019-10-15     Morocco         Gabon           2           3   Friendly
# 41219 2019-10-15        Peru       Uruguay           1           1   Friendly
#
# ...

# %%
newdata.groupby('tournament').goals.agg(['count','mean']).sort_values('mean')
# Out:
#                                       count      mean
# tournament
# COSAFA Cup                              292  2.219178
# Amílcar Cabral Cup                      235  2.246809
# African Cup of Nations qualification   1624  2.381773
# UEFA Euro                               286  2.402098
# UEFA Nations League                     142  2.408451
# African Cup of Nations                  690  2.421739
# Gulf Cup                                333  2.504505
# CECAFA Cup                              620  2.514516
# African Nations Championship            264  2.541667
# UNCAF Cup                               164  2.548780
# AFC Challenge Cup                       100  2.660000
# AFC Asian Cup                           370  2.667568
# Gold Cup                                327  2.761468
# UEFA Euro qualification                2532  2.815561
# FIFA World Cup                          900  2.831111
# UAFA Cup                                122  2.852459
# ...

# %%
newdata.groupby('tournament').goals.mean().sort_values().tail(20).plot(kind='barh')

# %%
# creating an empty list 
tlist = [] 

# number of elemetns as input 
n = int(input("Enter number of elements : "))

# iterating till the range 
for i in range(0, n): 
    ele = input()

    tlist.append(ele) # adding the element 

print(tlist)
# Out:
# Enter number of elements : 1
# FIFA World Cup qualification
# ['FIFA World Cup qualification']

# %%
newdata.groupby('tournament').goals.mean().sort_values().filter(tlist).plot(kind='barh')

# %%
# creating an empty list 
t2list = [] 

# number of elemetns as input 
n = int(input("Enter number of elements : "))

# iterating till the range 
for i in range(0, n): 
    ele = input()

    t2list.append(ele) # adding the element 

print(t2list)
# Out:
# Enter number of elements : 1
# FIFA World Cup qualification
# ['FIFA World Cup qualification']

# %%
last5years = data[data.date.dt.year >= 2015].groupby(data.date.dt.year).tournament.value_counts().unstack().fillna(0)

last5years[t2list]
# Out:
# tournament  FIFA World Cup qualification
# date
# 2015                               233.0
# 2016                               255.0
# 2017                               310.0
# 2018                                 0.0
# 2019                                 0.0

# %%
data['homewinner'] = data.home_score - data.away_score
data
# Out:
#             date     home_team   away_team  home_score  away_score  \
# 0     1872-11-30      Scotland     England           0           0
# 1     1873-03-08       England    Scotland           4           2
# 2     1874-03-07      Scotland     England           2           1
# 3     1875-03-06       England    Scotland           2           2
# 4     1876-03-04      Scotland     England           3           0
# ...          ...           ...         ...         ...         ...
# 41238 2019-10-20       Lesotho    Zimbabwe           0           0
# 41239 2019-10-20        Guinea     Senegal           1           0
# 41240 2019-10-20          Mali  Mauritania           2           0
# 41241 2019-10-20  Burkina Faso       Ghana           0           0
# 41242 2019-10-20   Ivory Coast       Niger           1           0
#
#                                     tournament          city       country  \
# 0                                     Friendly       Glasgow      Scotland
# ...

# %%
data['homeiswinner'] = (data['homewinner'] >= 1)
data
# Out:
#             date     home_team   away_team  home_score  away_score  \
# 0     1872-11-30      Scotland     England           0           0
# 1     1873-03-08       England    Scotland           4           2
# 2     1874-03-07      Scotland     England           2           1
# 3     1875-03-06       England    Scotland           2           2
# 4     1876-03-04      Scotland     England           3           0
# ...          ...           ...         ...         ...         ...
# 41238 2019-10-20       Lesotho    Zimbabwe           0           0
# 41239 2019-10-20        Guinea     Senegal           1           0
# 41240 2019-10-20          Mali  Mauritania           2           0
# 41241 2019-10-20  Burkina Faso       Ghana           0           0
# 41242 2019-10-20   Ivory Coast       Niger           1           0
#
#                                     tournament          city       country  \
# 0                                     Friendly       Glasgow      Scotland
# ...

# %%
homeiswinnercount = data.homeiswinner.value_counts()
homeiswinnercount
# Out:
# False    21190
# True     20053
# Name: homeiswinner, dtype: int64

# %%
newdata2 = data[data.homewinner >= 1]
newdata2
# Out:
#             date    home_team                 away_team  home_score  \
# 1     1873-03-08      England                  Scotland           4
# 2     1874-03-07     Scotland                   England           2
# 4     1876-03-04     Scotland                   England           3
# 5     1876-03-25     Scotland                     Wales           4
# 8     1878-03-02     Scotland                   England           7
# ...          ...          ...                       ...         ...
# 41235 2019-10-20        Congo         Equatorial Guinea           1
# 41236 2019-10-20     DR Congo  Central African Republic           4
# 41239 2019-10-20       Guinea                   Senegal           1
# 41240 2019-10-20         Mali                Mauritania           2
# 41242 2019-10-20  Ivory Coast                     Niger           1
#
#        away_score                               tournament         city  \
# 1               2                                 Friendly       London
# ...

# %%
newdata3 = data[data.homewinner < 0]
newdata3
# Out:
#             date                     home_team    away_team  home_score  \
# 6     1877-03-03                       England     Scotland           1
# 7     1877-03-05                         Wales     Scotland           0
# 12    1879-04-07                         Wales     Scotland           0
# 14    1880-03-15                         Wales      England           2
# 16    1881-02-26                       England        Wales           0
# ...          ...                           ...          ...         ...
# 41224 2019-10-15                         Aruba      Jamaica           0
# 41226 2019-10-15  United States Virgin Islands     Barbados           0
# 41227 2019-10-15                      Anguilla  Puerto Rico           2
# 41228 2019-10-18                         Sudan     Tanzania           1
# 41237 2019-10-20                         Libya      Tunisia           1
#
#        away_score                               tournament         city  \
# ...

# %%
data.groupby('homeiswinner').goals.mean().plot(kind='barh')

# %%
data.groupby('homeiswinner').goals.mean()
# Out:
# homeiswinner
# False    2.545729
# True     3.344886
# Name: goals, dtype: float64

# %%
neutralcount = data.neutral.value_counts()
neutralcount
# Out:
# False    31015
# True     10228
# Name: neutral, dtype: int64

# %%
newdata4 = data[data.neutral == 1]
newdata4
# Out:
#             date               home_team         away_team  home_score  \
# 68    1890-02-08                   Wales  Northern Ireland           5
# 262   1910-05-29                   Chile           Uruguay           0
# 326   1912-07-03                  Norway            Russia           2
# 428   1916-07-02                   Chile           Uruguay           0
# 431   1916-07-08                  Brazil             Chile           1
# ...          ...                     ...               ...         ...
# 41174 2019-10-13                 Ecuador         Argentina           1
# 41186 2019-10-13  British Virgin Islands           Bonaire           3
# 41201 2019-10-14            Sint Maarten        Guadeloupe           1
# 41214 2019-10-15                   Chile            Guinea           3
# 41224 2019-10-15                   Aruba           Jamaica           0
#
#        away_score               tournament          city  \
# ...

# %%
from scipy import stats
grps = pd.unique(data.tournament.values)
d_data = {grp:data['homeiswinner'][data.tournament == grp] for grp in grps}
 
F, p = stats.f_oneway(d_data['FIFA World Cup qualification'], d_data['Friendly'], d_data['Copa América'])
print("p-value for significance is: ", p)
if p<0.05:
    print("reject null hypothesis")
else:
    print("accept null hypothesis")
# Out:
# p-value for significance is:  1.0529730234463188e-10
# reject null hypothesis

# %%
p
# Out:
# 1.0529730234463188e-10

# %%
datafriendly = data.loc[data['tournament'].isin(['Friendly'])]
datafriendly = datafriendly.sample(100)
datafriendly
# Out:
#             date  home_team away_team  home_score  away_score tournament  \
# 19992 1996-11-07     Uganda    Rwanda           3           2   Friendly
# 10230 1977-09-07  German DR  Scotland           1           0   Friendly
# 26507 2004-05-29    Senegal    Guinea           1           1   Friendly
# 10734 1979-02-07      Libya    Greece           2           2   Friendly
# 18323 1994-06-01    Romania  Slovenia           0           0   Friendly
# ...          ...        ...       ...         ...         ...        ...
# 34239 2012-07-16   Botswana  Zimbabwe           1           0   Friendly
# 27943 2005-11-16     Cyprus     Wales           1           0   Friendly
# 12427 1982-12-26      Malta  Bulgaria           0           0   Friendly
# 23579 2001-02-18       Oman   Finland           1           2   Friendly
# 12816 1983-11-13      Niger      Mali           1           1   Friendly
#
#              city    country  neutral  goals  homewinner  homeiswinner
# ...

# %%
datacopa = data.loc[data['tournament'].isin(['Copa América'])]
datacopa = datacopa.sample(100)
datacopa
# Out:
#             date  home_team  away_team  home_score  away_score    tournament  \
# 3409  1953-03-08    Bolivia    Ecuador           1           1  Copa América
# 37028 2015-06-19      Chile    Bolivia           5           0  Copa América
# 2498  1945-02-07  Argentina   Colombia           9           1  Copa América
# 10924 1979-08-29    Ecuador   Paraguay           1           2  Copa América
# 29364 2007-07-07  Venezuela    Uruguay           1           4  Copa América
# ...          ...        ...        ...         ...         ...           ...
# 37981 2016-06-05    Jamaica  Venezuela           0           1  Copa América
# 14559 1987-07-02  Argentina    Ecuador           3           0  Copa América
# 15613 1989-07-01   Paraguay       Peru           5           2  Copa América
# 36997 2015-06-15      Chile     Mexico           3           3  Copa América
# 2381  1942-01-28    Uruguay   Paraguay           3           1  Copa América
#
# ...

# %%
dataqualification = data.loc[data['tournament'].isin(['FIFA World Cup qualification'])]
dataqualification = dataqualification.sample(100)
dataqualification
# Out:
#             date        home_team            away_team  home_score  \
# 38222 2016-09-05           Serbia  Republic of Ireland           2
# 13083 1984-06-24         Honduras               Panama           1
# 22755 2000-04-09            Libya                 Mali           3
# 20435 1997-04-30           Latvia              Belarus           2
# 16947 1992-06-03    Faroe Islands              Belgium           0
# ...          ...              ...                  ...         ...
# 5688  1964-10-21          Denmark                Wales           1
# 30325 2008-06-14     Sierra Leone         South Africa           1
# 38334 2016-10-09  North Macedonia                Italy           2
# 27872 2005-10-12          Austria     Northern Ireland           2
# 38254 2016-09-06         Thailand                Japan           0
#
#        away_score                    tournament         city          country  \
# 38222           2  FIFA World Cup qualification     Belgrade           Serbia
# ...

# %%
datatemp = pd.concat([datafriendly , dataqualification , datacopa ])
datatemp
# Out:
#             date  home_team  away_team  home_score  away_score    tournament  \
# 19992 1996-11-07     Uganda     Rwanda           3           2      Friendly
# 10230 1977-09-07  German DR   Scotland           1           0      Friendly
# 26507 2004-05-29    Senegal     Guinea           1           1      Friendly
# 10734 1979-02-07      Libya     Greece           2           2      Friendly
# 18323 1994-06-01    Romania   Slovenia           0           0      Friendly
# ...          ...        ...        ...         ...         ...           ...
# 37981 2016-06-05    Jamaica  Venezuela           0           1  Copa América
# 14559 1987-07-02  Argentina    Ecuador           3           0  Copa América
# 15613 1989-07-01   Paraguay       Peru           5           2  Copa América
# 36997 2015-06-15      Chile     Mexico           3           3  Copa América
# 2381  1942-01-28    Uruguay   Paraguay           3           1  Copa América
#
# ...

# %%
from scipy import stats
datatemp = datatemp[['homeiswinner','tournament']]
grps = pd.unique(datatemp.tournament.values)
d_data = {grp:datatemp['homeiswinner'][datatemp.tournament == grp] for grp in grps}
 
F, p = stats.f_oneway(d_data['FIFA World Cup qualification'], d_data['Friendly'], d_data['Copa América'])
print("p-value for significance is: ", p)
if p<0.05:
    print("reject null hypothesis")
else:
    print("accept null hypothesis")
# Out:
# p-value for significance is:  0.27560937424738036
# accept null hypothesis

# %%
p
# Out:
# 0.27560937424738036

# %%
from scipy.stats import ttest_ind
t_stat, p_val = ttest_ind(data['neutral'], data['goals'])

# %%
if p_val<0.05:
    print("reject null hypothesis")
else:
    print("accept null hypothesis")
# Out:
# reject null hypothesis

# %%
from scipy.stats import ttest_ind
t_stat, p_val = ttest_ind(data['homeiswinner'], data['goals'])
if p_val<0.05:
    print("reject null hypothesis")
else:
    print("accept null hypothesis")
# Out:
# reject null hypothesis

# %%
neutralcount = data.neutral.value_counts()
neutralcount
# Out:
# False    31015
# True     10228
# Name: neutral, dtype: int64

# %%
newdata4.country.value_counts()
# Out:
# United States                   761
# Malaysia                        428
# France                          355
# South Africa                    284
# United Arab Emirates            259
#                                ...
# Bahamas                           1
# United States Virgin Islands      1
# Bhutan                            1
# DR Congo                          1
# Dahomey                           1
# Name: country, Length: 222, dtype: int64

# %%
newdata4.groupby('country').country.value_counts().sort_values().tail(20).plot(kind='barh')

# %%
from scipy.stats import ttest_ind
t_stat, p_val = ttest_ind(data['homeiswinner'], data['neutral'])
if p_val<0.05:
    print("reject null hypothesis")
else:
    print("accept null hypothesis")
# Out:
# reject null hypothesis

# %%
datahost = data[data.neutral == 0]
datahost
# Out:
#             date     home_team   away_team  home_score  away_score  \
# 0     1872-11-30      Scotland     England           0           0
# 1     1873-03-08       England    Scotland           4           2
# 2     1874-03-07      Scotland     England           2           1
# 3     1875-03-06       England    Scotland           2           2
# 4     1876-03-04      Scotland     England           3           0
# ...          ...           ...         ...         ...         ...
# 41238 2019-10-20       Lesotho    Zimbabwe           0           0
# 41239 2019-10-20        Guinea     Senegal           1           0
# 41240 2019-10-20          Mali  Mauritania           2           0
# 41241 2019-10-20  Burkina Faso       Ghana           0           0
# 41242 2019-10-20   Ivory Coast       Niger           1           0
#
#                                     tournament          city       country  \
# 0                                     Friendly       Glasgow      Scotland
# ...

# %%
datahost = data[data.homeiswinner == 1]
datahost
# Out:
#             date    home_team                 away_team  home_score  \
# 1     1873-03-08      England                  Scotland           4
# 2     1874-03-07     Scotland                   England           2
# 4     1876-03-04     Scotland                   England           3
# 5     1876-03-25     Scotland                     Wales           4
# 8     1878-03-02     Scotland                   England           7
# ...          ...          ...                       ...         ...
# 41235 2019-10-20        Congo         Equatorial Guinea           1
# 41236 2019-10-20     DR Congo  Central African Republic           4
# 41239 2019-10-20       Guinea                   Senegal           1
# 41240 2019-10-20         Mali                Mauritania           2
# 41242 2019-10-20  Ivory Coast                     Niger           1
#
#        away_score                               tournament         city  \
# 1               2                                 Friendly       London
# ...

# %%
(datahost.homeiswinner.count() / data.neutral.count())*100
# Out:
# 48.62158426884562

# %%
datafriendlycount = data.loc[data['tournament'].isin(['Friendly'])]
datafriendlycount
# Out:
#             date   home_team     away_team  home_score  away_score tournament  \
# 0     1872-11-30    Scotland       England           0           0   Friendly
# 1     1873-03-08     England      Scotland           4           2   Friendly
# 2     1874-03-07    Scotland       England           2           1   Friendly
# 3     1875-03-06     England      Scotland           2           2   Friendly
# 4     1876-03-04    Scotland       England           3           0   Friendly
# ...          ...         ...           ...         ...         ...        ...
# 41215 2019-10-15     Denmark    Luxembourg           4           0   Friendly
# 41216 2019-10-15      Kuwait  Turkmenistan           1           1   Friendly
# 41217 2019-10-15  Mauritania         Libya           0           0   Friendly
# 41218 2019-10-15     Morocco         Gabon           2           3   Friendly
# 41219 2019-10-15        Peru       Uruguay           1           1   Friendly
#
# ...

# %%
datafriendlycount = datafriendlycount[['home_team','away_team','tournament']]

datafriendlycount
# Out:
#         home_team     away_team tournament
# 0        Scotland       England   Friendly
# 1         England      Scotland   Friendly
# 2        Scotland       England   Friendly
# 3         England      Scotland   Friendly
# 4        Scotland       England   Friendly
# ...           ...           ...        ...
# 41215     Denmark    Luxembourg   Friendly
# 41216      Kuwait  Turkmenistan   Friendly
# 41217  Mauritania         Libya   Friendly
# 41218     Morocco         Gabon   Friendly
# 41219        Peru       Uruguay   Friendly
#
# [17011 rows x 3 columns]

# %%
datafriendlycount.home_team.value_counts().sort_values().tail(20)
# Out:
# Tunisia          173
# Malawi           180
# Denmark          181
# Spain            187
# England          192
# Egypt            194
# Norway           197
# United States    217
# Brazil           227
# Italy            230
# Switzerland      239
# Netherlands      240
# Poland           243
# Belgium          243
# Austria          247
# Sweden           251
# Hungary          272
# Mexico           289
# France           291
# Germany          293
# Name: home_team, dtype: int64

# %%
datafriendlycount.away_team.value_counts().sort_values().tail(20)
# Out:
# Paraguay               183
# Romania                186
# Finland                193
# Norway                 193
# France                 195
# Belgium                201
# Trinidad and Tobago    204
# Brazil                 205
# Argentina              205
# Austria                206
# Bulgaria               207
# Russia                 208
# Uruguay                209
# Netherlands            209
# Switzerland            215
# England                216
# Germany                275
# Poland                 283
# Hungary                286
# Sweden                 287
# Name: away_team, dtype: int64

# %%
data['awayiswinner'] = (data['homewinner'] < 0)
data
# Out:
#             date     home_team   away_team  home_score  away_score  \
# 0     1872-11-30      Scotland     England           0           0
# 1     1873-03-08       England    Scotland           4           2
# 2     1874-03-07      Scotland     England           2           1
# 3     1875-03-06       England    Scotland           2           2
# 4     1876-03-04      Scotland     England           3           0
# ...          ...           ...         ...         ...         ...
# 41238 2019-10-20       Lesotho    Zimbabwe           0           0
# 41239 2019-10-20        Guinea     Senegal           1           0
# 41240 2019-10-20          Mali  Mauritania           2           0
# 41241 2019-10-20  Burkina Faso       Ghana           0           0
# 41242 2019-10-20   Ivory Coast       Niger           1           0
#
#                                     tournament          city       country  \
# 0                                     Friendly       Glasgow      Scotland
# ...

# %%
data['drawmatch'] = (data['homewinner'] == 0)
data
# Out:
#             date     home_team   away_team  home_score  away_score  \
# 0     1872-11-30      Scotland     England           0           0
# 1     1873-03-08       England    Scotland           4           2
# 2     1874-03-07      Scotland     England           2           1
# 3     1875-03-06       England    Scotland           2           2
# 4     1876-03-04      Scotland     England           3           0
# ...          ...           ...         ...         ...         ...
# 41238 2019-10-20       Lesotho    Zimbabwe           0           0
# 41239 2019-10-20        Guinea     Senegal           1           0
# 41240 2019-10-20          Mali  Mauritania           2           0
# 41241 2019-10-20  Burkina Faso       Ghana           0           0
# 41242 2019-10-20   Ivory Coast       Niger           1           0
#
#                                     tournament          city       country  \
# 0                                     Friendly       Glasgow      Scotland
# ...

# %%
databest = data[['home_team','away_team','homeiswinner','awayiswinner']]

databest
# Out:
#           home_team   away_team  homeiswinner  awayiswinner
# 0          Scotland     England         False         False
# 1           England    Scotland          True         False
# 2          Scotland     England          True         False
# 3           England    Scotland         False         False
# 4          Scotland     England          True         False
# ...             ...         ...           ...           ...
# 41238       Lesotho    Zimbabwe         False         False
# 41239        Guinea     Senegal          True         False
# 41240          Mali  Mauritania          True         False
# 41241  Burkina Faso       Ghana         False         False
# 41242   Ivory Coast       Niger          True         False
#
# [41243 rows x 4 columns]

# %%
newdata2
# Out:
#             date    home_team                 away_team  home_score  \
# 1     1873-03-08      England                  Scotland           4
# 2     1874-03-07     Scotland                   England           2
# 4     1876-03-04     Scotland                   England           3
# 5     1876-03-25     Scotland                     Wales           4
# 8     1878-03-02     Scotland                   England           7
# ...          ...          ...                       ...         ...
# 41235 2019-10-20        Congo         Equatorial Guinea           1
# 41236 2019-10-20     DR Congo  Central African Republic           4
# 41239 2019-10-20       Guinea                   Senegal           1
# 41240 2019-10-20         Mali                Mauritania           2
# 41242 2019-10-20  Ivory Coast                     Niger           1
#
#        away_score                               tournament         city  \
# 1               2                                 Friendly       London
# ...

# %%
newdata2.home_team.value_counts()
# Out:
# Brazil                           403
# Argentina                        361
# Germany                          315
# England                          304
# Mexico                           301
#                                 ...
# Western Armenia                    1
# Timor-Leste                        1
# St Vincent and the Grenadines      1
# Arameans Suryoye                   1
# San Marino                         1
# Name: home_team, Length: 292, dtype: int64

# %%
newdata3
# Out:
#             date                     home_team    away_team  home_score  \
# 6     1877-03-03                       England     Scotland           1
# 7     1877-03-05                         Wales     Scotland           0
# 12    1879-04-07                         Wales     Scotland           0
# 14    1880-03-15                         Wales      England           2
# 16    1881-02-26                       England        Wales           0
# ...          ...                           ...          ...         ...
# 41224 2019-10-15                         Aruba      Jamaica           0
# 41226 2019-10-15  United States Virgin Islands     Barbados           0
# 41227 2019-10-15                      Anguilla  Puerto Rico           2
# 41228 2019-10-18                         Sudan     Tanzania           1
# 41237 2019-10-20                         Libya      Tunisia           1
#
#        away_score                               tournament         city  \
# ...

# %%
newdata3.away_team.value_counts()
# Out:
# England         262
# Germany         238
# Brazil          222
# Sweden          215
# Uruguay         191
#                ...
# Tuvalu            1
# Anguilla          1
# Matabeleland      1
# Andalusia         1
# Brittany          1
# Name: away_team, Length: 286, dtype: int64
